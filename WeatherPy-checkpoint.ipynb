# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import os 
import csv
# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 604

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}appid={weather_api_key}&units={units}&q="


weather_response = requests.get(query_url + city)
weather_json = weather_response.json()

# %%
city_df = []
country_df = []
date_df = []
lat_vol = []
lon_vol = []
temperature = []
humidity = []
cloudiness = []
wind_speed_df = []

# %%
processing_data = 1

# Loop Through List of Cities & Perform a Request for Data on Each city
for city in cities:

# Exception Handling
    try:
        response = requests.get(query_url + city).json()
        
        city_df.append(response["name"])
        
        country_df.append(response["sys"]["country"])
        date_df.append(response["dt"])
        lat_vol.append(response["coord"]["lat"])
        lon_vol.append(response["coord"]["lon"])
        temperature.append(response["main"]["temp_max"])
        humidity.append(response["main"]["humidity"])
        cloudiness.append(response["clouds"]["all"])
        wind_speed_df.append(response["wind"]["speed"])
        
        city_data = response["name"]
        
        print(f"searching for Record {processing_data} {city_data}")
        
         # Increase data Counter by 1 For Each Loop
        processing_data += 1
        
    except(KeyError):
        print("message: city not found") 
    continue
# Out:
# searching for Record 1 Guhāgar
# searching for Record 2 Jamestown
# searching for Record 3 Talnakh
# searching for Record 4 Albany
# message: city not found
# searching for Record 5 Kapaa
# searching for Record 6 Mataura
# searching for Record 7 Goderich
# searching for Record 8 Hobyo
# searching for Record 9 Vaini
# searching for Record 10 East London
# searching for Record 11 Florence
# searching for Record 12 Mossamedes
# searching for Record 13 Rikitea
# searching for Record 14 Cape Town
# searching for Record 15 Bethel
# searching for Record 16 Clyde River
# searching for Record 17 Avera
# searching for Record 18 Ambilobe
# searching for Record 19 Tiksi
# searching for Record 20 Hermanus
# searching for Record 21 Khorinsk
# searching for Record 22 Ribeira Grande
# searching for Record 23 Talara
# searching for Record 24 Lerwick
# searching for Record 25 Bredasdorp
# searching for Record 26 Bluff
# searching for Record 27 Kruisfontein
# searching for Record 28 Qaanaaq
# searching for Record 29 Ponta do Sol
# searching for Record 30 Arraial do Cabo
# searching for Record 31 Ushuaia
# searching for Record 32 Kawalu
# searching for Record 33 Mayma
# searching for Record 34 Kimbe
# searching for Record 35 Laguna
# searching for Record 36 Cidreira
# searching for Record 37 Makakilo City
# searching for Record 38 Awjilah
# searching for Record 39 Nikolskoye
# message: city not found
# searching for Record 40 Port Alfred
# searching for Record 41 Punta Arenas
# searching for Record 42 Hojāi
# searching for Record 43 Te Anau
# searching for Record 44 Simao
# message: city not found
# searching for Record 45 Benito Juarez
# searching for Record 46 Mar del Plata
# searching for Record 47 Upernavik
# searching for Record 48 Lesogorskiy
# searching for Record 49 Dunedin
# searching for Record 50 Aswān
# searching for Record 51 Barrow
# searching for Record 52 Hokitika
# searching for Record 53 Lavrentiya
# searching for Record 54 Shimoda
# searching for Record 55 Busselton
# searching for Record 56 Nizwá
# message: city not found
# message: city not found
# searching for Record 57 Pisco
# searching for Record 58 Hobart
# searching for Record 59 Butaritari
# searching for Record 60 Castro
# searching for Record 61 Fortuna
# searching for Record 62 Lüderitz
# searching for Record 63 Saint-Philippe
# searching for Record 64 Ancud
# searching for Record 65 Nouadhibou
# searching for Record 66 Carnarvon
# searching for Record 67 São Filipe
# searching for Record 68 Acajutla
# searching for Record 69 Sehithwa
# searching for Record 251 Yei
# message: city not found
# searching for Record 252 Tateyama
# searching for Record 253 Pacific Grove
# searching for Record 254 Muncar
# searching for Record 255 Tarakan
# searching for Record 256 Sistranda
# searching for Record 257 Birjand
# searching for Record 258 Barstow
# searching for Record 259 Erenhot
# searching for Record 260 Kyabé
# searching for Record 261 College
# searching for Record 262 Arlit
# searching for Record 263 Kostomuksha
# searching for Record 264 Assaré
# searching for Record 265 Vilcún
# searching for Record 266 Nguruka
# message: city not found
# searching for Record 267 Bonavista
# searching for Record 268 Leiyang
# searching for Record 269 Novoil'insk
# searching for Record 270 Batagay
# searching for Record 271 Fort Nelson
# searching for Record 272 Yatou
# searching for Record 273 Huntingdon
# searching for Record 274 Sabinópolis
# searching for Record 275 Aldan
# searching for Record 276 Ust-Kuyga
# searching for Record 277 Puerto Baquerizo Moreno
# searching for Record 278 Plainview
# searching for Record 279 Reftinskiy
# searching for Record 280 Blairmore
# searching for Record 281 Zhezkazgan
# searching for Record 282 Alappuzha
# searching for Record 283 Soledade
# searching for Record 284 Calama
# searching for Record 285 Zhengjiatun
# searching for Record 286 São Félix do Xingu
# searching for Record 287 Yumen
# searching for Record 288 Ogulin
# searching for Record 289 Ixtapa
# searching for Record 290 Poopó
# searching for Record 291 Nago
# searching for Record 292 Esperance
# searching for Record 293 Gobabis
# searching for Record 294 Kitimat
# searching for Record 295 Caucayá
# searching for Record 296 Defiance
# searching for Record 297 Shakawe
# searching for Record 298 Mulegé
# searching for Record 299 Humboldt
# searching for Record 300 Jining
# searching for Record 301 Armidale
# searching for Record 302 Pangody
# searching for Record 303 Kavieng
# searching for Record 304 Popondetta
# searching for Record 305 Camacupa
# searching for Record 306 Buchanan
# searching for Record 307 Hayden
# searching for Record 308 Hamilton
# searching for Record 309 Morro Bay
# searching for Record 310 Tres Arroyos
# searching for Record 311 Mizdah
# searching for Record 312 Luanda
# message: city not found
# searching for Record 313 Balad
# searching for Record 314 Coos Bay
# searching for Record 315 Homer
# searching for Record 316 Muroto-misakicho
# searching for Record 317 Puerto Escondido
# message: city not found
# searching for Record 318 Severnyy
# searching for Record 319 Urengoy
# searching for Record 320 Dingle
# searching for Record 321 Grindavik
# searching for Record 322 Ganj Dundwāra
# searching for Record 323 Beyneu
# searching for Record 324 Çan
# searching for Record 325 Tawang Town
# message: city not found
# searching for Record 326 Provideniya
# searching for Record 327 Ulaanbaatar
# searching for Record 328 Weiser
# searching for Record 329 Alekseyevsk
# searching for Record 330 Hereford
# searching for Record 331 Tutóia
# searching for Record 332 Lebu
# searching for Record 333 Portland
# searching for Record 334 Atbasar
# searching for Record 335 Qaqortoq
# searching for Record 336 Mumford
# searching for Record 337 Dzaoudzi
# searching for Record 338 Sinegor'ye
# searching for Record 339 Key West
# searching for Record 340 Bhaderwah
# searching for Record 341 Susanino
# searching for Record 342 Solnechnyy
# searching for Record 343 Kaitangata
# searching for Record 344 Jamame
# searching for Record 437 Kloulklubed
# searching for Record 438 Pinega
# searching for Record 439 Sibolga
# searching for Record 440 Laguna de Duero
# searching for Record 441 Alofi
# searching for Record 442 Lagos
# searching for Record 443 Bunawan
# searching for Record 444 Gurh
# searching for Record 445 Kumul
# searching for Record 446 Nanortalik
# searching for Record 447 Caceres
# searching for Record 448 Ostrovnoy
# searching for Record 449 Mikró Monastíri
# searching for Record 450 Simbahan
# searching for Record 451 Coyhaique
# searching for Record 452 Lamar
# searching for Record 453 Cayenne
# searching for Record 454 Baturaja
# searching for Record 455 Sørland
# searching for Record 456 São José do Belmonte
# searching for Record 457 Walvis Bay
# searching for Record 458 Harper
# searching for Record 459 Santo Domingo
# searching for Record 460 Teknāf
# searching for Record 461 Golden
# searching for Record 462 Kodoli
# searching for Record 463 Chilca
# message: city not found
# searching for Record 464 Atar
# searching for Record 465 Grand-Santi
# searching for Record 466 Madridejos
# searching for Record 467 Khorixas
# searching for Record 468 Iskateley
# searching for Record 469 Anori
# searching for Record 470 Richards Bay
# searching for Record 471 Province of Mantua
# searching for Record 472 Aksarka
# searching for Record 473 Kuli
# searching for Record 474 Port Blair
# searching for Record 475 West Monroe
# searching for Record 476 Saint-Pierre
# searching for Record 477 Mola di Bari
# searching for Record 478 Fulton
# searching for Record 479 Denpasar
# searching for Record 480 Hirara
# searching for Record 481 Yabassi
# searching for Record 482 Auki
# searching for Record 483 Durango
# searching for Record 484 Bakel
# searching for Record 485 Ust-Nera
# searching for Record 486 Pinawa
# searching for Record 487 Askino
# searching for Record 488 Neuquén
# searching for Record 489 Touros
# searching for Record 490 Bathsheba
# searching for Record 491 Khovd
# searching for Record 492 Ciudad Bolivar
# searching for Record 493 Bulgan
# searching for Record 494 Lieksa
# searching for Record 495 Santa Maria
# searching for Record 496 Bismarck
# searching for Record 497 Husavik
# searching for Record 498 Provincia di Imperia
# searching for Record 499 Colares
# searching for Record 500 Vao
# searching for Record 501 Yārāda
# searching for Record 502 Presidencia Roque Sáenz Peña
# searching for Record 503 Marabu
# searching for Record 504 Manggar
# searching for Record 505 Mishan
# searching for Record 506 Berlevåg
# searching for Record 507 Bam
# searching for Record 508 Grand Gaube
# searching for Record 509 Lompoc
# message: city not found
# searching for Record 510 Maceió
# message: city not found
# searching for Record 511 Arman'
# searching for Record 512 Røros
# searching for Record 513 Caconda
# searching for Record 514 Mollendo
# searching for Record 515 Chivay
# searching for Record 516 Călăraşi
# searching for Record 517 Byron Bay
# searching for Record 518 Ishigaki
# searching for Record 519 Astoria
# searching for Record 520 La Ronge
# searching for Record 521 La Sarre
# searching for Record 522 Hidalgo
# searching for Record 523 Makueni Boma
# searching for Record 524 Poum
# searching for Record 525 Malindi
# searching for Record 526 Butterworth
# searching for Record 527 Jaggayyapeta
# searching for Record 528 Ust'-Omchug
# searching for Record 529 Riwaka
# searching for Record 530 Entebbe
# searching for Record 531 Krasnosel'kup
# searching for Record 532 Lahān
# searching for Record 533 Arica
# searching for Record 534 Sambava
# searching for Record 535 Tsabong
# searching for Record 536 Caxias
# searching for Record 537 Kemijärvi
# searching for Record 538 Bull Savanna
# searching for Record 539 Port-Gentil
# searching for Record 540 Salima
# message: city not found
# searching for Record 541 Alberton
# searching for Record 542 Gull Lake
# searching for Record 543 Fort-Shevchenko
# searching for Record 544 Dali
# searching for Record 545 Hue
# searching for Record 546 San Cristobal
# searching for Record 547 Coldwater
# message: city not found
# searching for Record 548 Rodolfo Sánchez Taboada
# message: city not found
# message: city not found
# searching for Record 549 Moerai
# searching for Record 550 Severodvinsk
# searching for Record 551 Ürümqi
# searching for Record 552 Mayor Pablo Lagerenza
# searching for Record 553 Yeppoon
# searching for Record 554 Ziro
# searching for Record 555 Luan
# searching for Record 556 Buin
# searching for Record 557 Forio
# searching for Record 558 Saint-Augustin
# message: city not found
# searching for Record 559 Samaná

# %%
# weather_json

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_dict = {
    "City": city_df,
    "Country": country_df,
    "Date": date_df,
    "Latitude": lat_vol,
    "Longitude": lon_vol,
    "Max Temperature": temperature,
    "Humidity": humidity,
    "Cloudiness": cloudiness,
    "Wind Speed": wind_speed_df
}

weather_df = pd.DataFrame(weather_dict)
weather_df.count()
# Out:
# City               559
# Country            559
# Date               559
# Latitude           559
# Longitude          559
# Max Temperature    559
# Humidity           559
# Cloudiness         559
# Wind Speed         559
# dtype: int64

# %%
weather_df.head()
# Out:
#         City Country        Date  Latitude  Longitude  Max Temperature  \
# 0    Guhāgar      IN  1597863176     17.48      73.19            78.71
# 1  Jamestown      US  1597863341     42.10     -79.24            69.01
# 2    Talnakh      RU  1597863341     69.49      88.40            55.40
# 3     Albany      US  1597862517     42.60     -73.97            75.99
# 4      Kapaa      US  1597863342     22.08    -159.32            80.01
#
#    Humidity  Cloudiness  Wind Speed
# 0        88         100       10.20
# 1        55          40        9.17
# 2        54           0        8.95
# 3        53          75        9.17
# 4        78          75       11.41

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

weather_df_val = weather_df.dropna()

weather_df_val = weather_df_val.reset_index(drop=True)

weather_df_val["City"] = weather_df_val["City"]

# %%
# Extract relevant fields from the data frame
# Export the City_Data into a csv

#weather_df.to_csv("./ouput_data/weather_df.csv")
weather_df.to_csv("../output_data/weather_df.csv",index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
weather_plot1 = weather_df_val["Date"][0]

plt.scatter(weather_df_val["Latitude"], weather_df_val["Max Temperature"], facecolor="blue", marker="o",edgecolors='black')

# set graph properties
plt.title("City Latitude vs. Temperature {weather_plot1}")
plt.ylabel("Temperature (°F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("Temp_Latitude.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
weather_plot2 = weather_df_val["Date"][0]

plt.scatter(weather_df_val["Latitude"], weather_df_val["Humidity"], facecolor="blue", marker="o",edgecolors='black')

# set graph properties
plt.title("City Latitude vs. Humaidity {weather_plot2}")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("Humidity_Latitude.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
weather_plot3 = weather_df_val["Date"][0]

plt.scatter(weather_df_val["Latitude"], weather_df_val["Cloudiness"], facecolor="blue", marker="o",edgecolors='black')

# set graph properties
plt.title("City Latitude vs. Cloudiness {weather_plot3}")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("Cloudiness_Latitude.png")
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
weather_plot4 = weather_df_val["Date"][0]

plt.scatter(weather_df_val["Latitude"], weather_df_val["Wind Speed"], facecolor="blue", marker="o",edgecolors='black')

# set graph properties
plt.title("City Latitude vs. Wind Speed {weather_plot4}")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the plot
plt.savefig("Wind_Speed_Latitude.png")
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
def plot_lin_reg(x_value,y_value,xlbl,ylbl,lblpos,ifigure):
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_value, y_value)
    
    regress_values = x_value * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    
    plt.scatter(x_value,y_value)
    plt.plot(x_value,regress_values,"r-")
    
    plt.annotate(line_eq,lblpos,fontsize=14,color="blue")
    print(f"The r-squared is: {rvalue}")
    plt.xlabel(xlbl)
    plt.ylabel(ylbl)
    
    plt.savefig(f"fig{ifigure}.png")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames

hem_northern_df = weather_df_val.Latitude >= 0
hem_southtern_df = weather_df_val.Latitude < 0

weather_northern = weather_df_val[hem_northern_df]
weather_southern = weather_df_val[hem_southtern_df]

weather_northern = weather_northern.reset_index(drop=True)
weather_southern = weather_southern.reset_index(drop=True)

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Max Temperature"
lblpos = (0,20)
plt.title("North Hemisphere Max Tem vs. Lat Linear Reg")
plot_lin_reg(weather_northern[xlbl],weather_northern[ylbl],xlbl,ylbl,lblpos,1)
plt.savefig("Hem_reg fig1")
# Out:
# The r-squared is: -0.7324725526086228

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Max Temperature"
lblpos = (-45,90)
plt.title("South Hemisphere Max Tem vs. Lat Linear Reg")
plot_lin_reg(weather_southern[xlbl],weather_southern[ylbl],xlbl,ylbl,lblpos,2)
# Out:
# The r-squared is: 0.8120489373430146

# %% [markdown]
# Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (40,15)
plt.title("North Hemisphere Humidity vs. Lat Linear Reg")
plot_lin_reg(weather_northern[xlbl],weather_northern[ylbl],xlbl,ylbl,lblpos,3)
# Out:
# The r-squared is: 0.03926284473259991

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Humidity"
lblpos = (-50,20)
plt.title("South Hemisphere Humidity vs. Lat Linear Reg")
plot_lin_reg(weather_southern[xlbl],weather_southern[ylbl],xlbl,ylbl,lblpos,4)
# Out:
# The r-squared is: -0.09615736073999219

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (10,30)
plt.title("North Hemisphere Humidity (%) vs. Lat Linear Reg")
plot_lin_reg(weather_northern[xlbl],weather_northern[ylbl],xlbl,ylbl,lblpos,5)
# Out:
# The r-squared is: 0.023985694279532878

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Cloudiness"
lblpos = (-50,45)
plt.title("South Hemisphere Cloudiness vs. Lat Linear Reg")
plot_lin_reg(weather_southern[xlbl],weather_southern[ylbl],xlbl,ylbl,lblpos,6)
# Out:
# The r-squared is: 0.06919389382463233

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (0,20)
plt.title("North Hemisphere Wind Speen (mph) vs. Lat Linear Reg")
plot_lin_reg(weather_northern[xlbl],weather_northern[ylbl],xlbl,ylbl,lblpos,7)
# Out:
# The r-squared is: -0.04964953740507937

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
xlbl = "Latitude"
ylbl = "Wind Speed"
lblpos = (-20,34)
plt.title("South Hemisphere Wind Speed (%) vs. Lat Linear Reg")
plot_lin_reg(weather_southern[xlbl],weather_southern[ylbl],xlbl,ylbl,lblpos,8)
# Out:
# The r-squared is: -0.12231573864268959

# %%
Observations:
The temperature VS. latitude plot shows an increase of temperature with increase in latitude on Southern Hemisphere. 
There almost no relationship between humidity and level of temperature on both southern and northern Hemisphere. 
The data on wind speed vs. latitude also does not show any positive or negative relationship between wind speed and latitude.
